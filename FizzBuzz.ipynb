# %%
for i in range (1,101):
    if (i % 3 == 0) and (i % 5 == 0):
        print ("FizzBuzz")
    elif i % 3 == 0:
        print("Fizz") 
    elif i % 5 == 0:
        print ("Fuzz")
    else:
        print(i)
# Out:
# 1
# 2
# Fizz
# 4
# Fuzz
# Fizz
# 7
# 8
# Fizz
# Fuzz
# 11
# Fizz
# 13
# 14
# FizzBuzz
# 16
# 17
# Fizz
# 19
# Fuzz
# Fizz
# 22
# 23
# Fizz
# Fuzz
# 26
# Fizz
# 28
# 29
# FizzBuzz
# 31
# 32
# Fizz
# 34
# Fuzz
# Fizz
# 37
# 38
# Fizz
# Fuzz
# 41
# Fizz
# 43
# 44
# FizzBuzz
# 46
# 47
# Fizz
# 49
# Fuzz
# Fizz
# 52
# 53
# Fizz
# Fuzz
# 56
# Fizz
# 58
# 59
# FizzBuzz
# 61
# 62
# Fizz
# 64
# Fuzz
# Fizz
# 67
# 68
# Fizz
# Fuzz
# 71
# Fizz
# 73
# 74
# FizzBuzz
# 76
# 77
# Fizz
# 79
# Fuzz
# Fizz
# 82
# 83
# Fizz
# Fuzz
# 86
# Fizz
# 88
# 89
# FizzBuzz
# 91
# 92
# Fizz
# 94
# Fuzz
# Fizz
# 97
# 98
# Fizz
# Fuzz
